# %%
import pandas as pd
from analytics_workbench.read_data import DataReader
from analytics_workbench.preprocessing import PreProcessor
from analytics_workbench.process_text import ProcessText
from analytics_workbench.unsupervised_learning import Unsupervised
from analytics_workbench.supervised_learning import ClassificationModelCV
from analytics_workbench.model_diagnostics import ClassificationModelDiagnotstics
from sklearn import metrics
import xgboost as xgb
from sklearn import model_selection, preprocessing, ensemble
from sklearn.metrics import log_loss,f1_score
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC,SVC
from sklearn.multiclass import OneVsRestClassifier
import dill
import pickle
import cPickle

# %%
df = pd.read_csv('/home/madan/Desktop/joswin_bck/toPendrive/works/company_classification/nlp-intelligence/e-commerce_classification/alexa_based/input_dataframe')

# %%
df.head()
# Out:
#              domain              category  \
# 0         11x17.com       Office_Products
# 1  a1components.com  Consumer_Electronics
# 2       a1darts.com        Sporting_Goods
# 3       a1-dogs.com                  Pets
# 4    a1florists.com               Flowers
#
#                                            url_texts  \
# 0  Home Contact About Login or Register My Accoun...
# 1  Login My Account Help View Cart\n        (0)\n...
# 2                                                NaN
# 3  HOME DOG PRODUCTS Â Here's \n              how...
# 4  Cities and Towns Business Cards Home\nPage Cit...
#
#                                            page_text
# 0   .pr stars background image url http cdn.power...
# 1   Audio Video Tools Cables Speakers Networking ...
# 2   Error. Page cannot be displayed. Please conta...
# 3   dog products dog supplies and dog accessories...
# 4   Canada s frendliest florists delivering flowe...

# %%
text_processor = ProcessText()
tfidf,vocabulary = text_processor.gen_dtm_from_files(df['page_text'],vectorizer_type='Tfidf',stem_type=None,
                                                     max_df=0.9,min_df=0.01,
                    n_gram_range=(1,1),stop_words_loc='/home/madan/Desktop/joswin_bck/toPendrive/works/company_classification/nlp-intelligence/e-commerce_classification/alexa_based/stopwords.txt')

tfidf.shape
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-968d13f74487> in <module>()
#       2 tfidf,vocabulary = text_processor.gen_dtm_from_files(df['page_text'],vectorizer_type='Tfidf',stem_type=None,
#       3                                                      max_df=0.9,min_df=0.01,
# ----> 4                     n_gram_range=(1,1),stop_words_loc='/home/madan/Desktop/joswin_bck/toPendrive/works/company_classification/nlp-intelligence/e-commerce_classification/alexa_based/stopwords.txt')
#       5
#       6 tfidf.shape
#
# /home/madan/Desktop/joswin_bck/toPendrive/works/analytics_work_bench/nlp-intelligence/analytics_workbench/analytics_workbench/process_text.pyc in gen_dtm_from_files(self, text_documents, vectorizer_type, synonym_loc, stem_type, phrase_generation, stop_words_loc, lower, n_gram_range, max_df, min_df, vocabulary_loc, **kwargs)
#     212             text_documents=text_documents,vectorizer_type=vectorizer_type,synonyms_dic=synonyms_dic,stem_type=stem_type,
#     213             phrase_generation=phrase_generation,stop_words=stop_words,lower=lower,n_gram_range=n_gram_range,
# --> 214             max_df=max_df,min_df=min_df,vocabulary=self.vocabulary,**kwargs
#     215         )
#     216
#
# /home/madan/Desktop/joswin_bck/toPendrive/works/analytics_work_bench/nlp-intelligence/analytics_workbench/analytics_workbench/process_text.pyc in gen_document_term_matrix(self, text_documents, vectorizer_type, synonyms_dic, stem_type, phrase_generation, stop_words, lower, n_gram_range, max_df, min_df, vocabulary, **kwargs)
#     156                                       stop_words=stop_words,lower=lower,n_gram_range=n_gram_range,max_df=max_df,min_df=min_df,
#     157                                       vocabulary=vocabulary,**kwargs)
# --> 158         dtm = self.vectorizer.fit_transform(text_series)
#     159         self.vocabulary = self.get_vectorizer_vocabulary(self.vectorizer)
#     160         return dtm,self.vocabulary
#
# /usr/local/lib/python2.7/dist-packages/sklearn/feature_extraction/text.pyc in fit_transform(self, raw_documents, y)
#    1350             Tf-idf-weighted document-term matrix.
#    1351         """
# -> 1352         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1353         self._tfidf.fit(X)
#    1354         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python2.7/dist-packages/sklearn/feature_extraction/text.pyc in fit_transform(self, raw_documents, y)
#     837
#     838         vocabulary, X = self._count_vocab(raw_documents,
# --> 839                                           self.fixed_vocabulary_)
#     840
#     841         if self.binary:
#
# /usr/local/lib/python2.7/dist-packages/sklearn/feature_extraction/text.pyc in _count_vocab(self, raw_documents, fixed_vocab)
#     760         for doc in raw_documents:
#     761             feature_counter = {}
# --> 762             for feature in analyze(doc):
#     763                 try:
#     764                     feature_idx = vocabulary[feature]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/feature_extraction/text.pyc in <lambda>(doc)
#     239
#     240             return lambda doc: self._word_ngrams(
# --> 241                 tokenize(preprocess(self.decode(doc))), stop_words)
#     242
#     243         else:
#
# /home/madan/Desktop/joswin_bck/toPendrive/works/analytics_work_bench/nlp-intelligence/analytics_workbench/analytics_workbench/process_text.pyc in <lambda>(text)
#     170         else:
#     171             self.vectorizer = TfidfVectorizer(decode_error='ignore',
# --> 172                     tokenizer=lambda text: tokenizer(text,stem_type=stem_type,phrase_generation=phrase_generation),
#     173                     lowercase=lower,ngram_range=n_gram_range,max_df=max_df,min_df=min_df,vocabulary=vocabulary,
#     174                     stop_words=stop_words,**kwargs)
#
# /home/madan/Desktop/joswin_bck/toPendrive/works/analytics_work_bench/nlp-intelligence/analytics_workbench/analytics_workbench/process_text.pyc in tokenizer(text, stem_type, phrase_generation, synonyms)
#      77         tokens = word_tokenize(reg_exp.sub(' ',' '.join(wrds)))
#      78     else:
# ---> 79         tokens = word_tokenize(reg_exp.sub(' ',text))
#      80     if synonyms:
#      81         # todo: need to add this
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/__init__.pyc in word_tokenize(text, language)
#     103     """
#     104     return [token for sent in sent_tokenize(text, language)
# --> 105             for token in _treebank_word_tokenize(sent)]
#     106
#
# /usr/local/lib/python2.7/dist-packages/nltk/tokenize/treebank.pyc in tokenize(self, text)
#      94             text = regexp.sub(r' \1 \2 ', text)
#      95         for regexp in self.CONTRACTIONS3:
# ---> 96             text = regexp.sub(r' \1 \2 ', text)
#      97
#      98         # We are not using CONTRACTIONS4 since
#
# KeyboardInterrupt:

# %%
with open('/home/madan/Desktop/joswin_bck/toPendrive/works/company_classification/nlp-intelligence/e-commerce_classification/alexa_based/page_text_tfidf.pkl','w') as f:
    dill.dump({'text_processor':text_processor,'tfidf':tfidf,'vocabulary':vocabulary},f)

# %%
text_processor = ProcessText()
tfidf,vocabulary = text_processor.gen_dtm_from_files(df['url_texts'],vectorizer_type='Tfidf',stem_type=None,
                                                     max_df=0.9,min_df=0.01,
                    n_gram_range=(1,1),stop_words_loc='/home/madan/Desktop/joswin_bck/toPendrive/works/company_classification/nlp-intelligence/e-commerce_classification/alexa_based/stopwords.txt')

tfidf.shape
# Out:
# (12594, 1592)

# %%
with open('/home/madan/Desktop/joswin_bck/toPendrive/works/company_classification/nlp-intelligence/e-commerce_classification/alexa_based/url_texts_tfidf.pkl','w') as f:
    dill.dump({'text_processor':text_processor,'tfidf':tfidf,'vocabulary':vocabulary},f)

# %%
df.drop('page_text', axis=1, inplace=True)
df.drop('url_texts', axis=1, inplace=True)

# %% [markdown]
# #### classification model

# %%
with open('/home/madan/Desktop/joswin_bck/toPendrive/works/company_classification/nlp-intelligence/e-commerce_classification/alexa_based/page_text_tfidf.pkl','r') as f:
    page_text_dic = pickle.load(f)

# %%
with open('/home/madan/Desktop/joswin_bck/toPendrive/works/company_classification/nlp-intelligence/e-commerce_classification/alexa_based/url_texts_tfidf.pkl','r') as f:
    url_text_dic = pickle.load(f)

# %%
from scipy.sparse import hstack

# %%
tfidf = hstack([page_text_dic['tfidf'],url_text_dic['tfidf']]).tocsr()

# %%
df.loc[df['category'].isin(['Holidays_and_Celebrations','Beauty_Products','Crafts']),'category'] = 'other_categories_1'
df.loc[df['category'].isin(['Auctions', 'Publications', 'Computers', 'Consumer_Information', 'Death_Care', 'Health',
                          'Travel_Items', 'Sports', 'Toys_and_Games', 'Ethnic_and_Regional', 'Tools', 'Niche', 
                          'Weddings', 'Holidays', 'Tobacco']),'category'] = 'other_categories_2'
df['category'].value_counts()
# Out:
# Home_and_Garden              1568
# Clothing                     1136
# other_categories_2           1063
# Sporting_Goods               1040
# Food                          773
# Recreation                    684
# Antiques_and_Collectibles     641
# Consumer_Electronics          640
# Pets                          494
# Jewelry                       492
# Music                         433
# Entertainment                 405
# Health_and_Healthcare         380
# Books                         363
# General_Merchandise           353
# Gifts                         331
# Children                      330
# other_categories_1            315
# Other                         258
# Flowers                       258
# Office_Products               252
# Photography                   218
# Classifieds                   167
# Name: category, dtype: int64

# %%
lbl = preprocessing.LabelEncoder()
categories_transformed = lbl.fit_transform(df['category'].values)

# %%
predictions = np.zeros(categories_transformed.shape)

cv_f1_scores,cv_log_loss = [],[]
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
for dev_index, val_index in kf.split(range(tfidf.shape[0])):
        dev_X, val_X = tfidf[dev_index,:], tfidf[val_index,:]
        dev_y, val_y = categories_transformed[dev_index], categories_transformed[val_index]
        clf = LinearSVC(C=0.2)
        clf.fit(dev_X,dev_y)
        preds_labels = clf.predict(val_X)
        predictions[val_index] = preds_labels
        cv_f1_scores.append(f1_score(val_y, preds_labels,average='weighted'))
        #cv_log_loss.append(log_loss(val_y,preds_labels))
        print(cv_f1_scores)
        #print(cv_log_loss)
# Out:
# [0.51039969821862263]
# [0.51039969821862263, 0.52724863785420617]
# [0.51039969821862263, 0.52724863785420617, 0.52139352745904977]
# [0.51039969821862263, 0.52724863785420617, 0.52139352745904977, 0.51546986185172594]
# [0.51039969821862263, 0.52724863785420617, 0.52139352745904977, 0.51546986185172594, 0.52283009923841939]

# %%
print metrics.classification_report(categories_transformed,predictions,labels=range(23),target_names=list(lbl.classes_))
pd.DataFrame(metrics.confusion_matrix(categories_transformed,predictions),columns=list(lbl.classes_),index=list(lbl.classes_))
# Out:
#                            precision    recall  f1-score   support
#
# Antiques_and_Collectibles       0.47      0.39      0.43       641
#                  Auctions       0.41      0.09      0.15        77
#           Beauty_Products       0.66      0.60      0.63       194
#                     Books       0.52      0.42      0.46       363
#                  Children       0.65      0.45      0.53       330
#               Classifieds       0.64      0.69      0.67       167
#                  Clothing       0.44      0.63      0.52      1136
#                 Computers       0.57      0.56      0.57       500
#      Consumer_Electronics       0.64      0.55      0.59       640
#      Consumer_Information       0.27      0.06      0.09       106
#                    Crafts       0.00      0.00      0.00         6
#                Death_Care       0.00      0.00      0.00         9
#             Entertainment       0.53      0.44      0.48       405
#       Ethnic_and_Regional       0.00      0.00      0.00         4
#                   Flowers       0.84      0.78      0.80       258
#                      Food       0.66      0.72      0.69       773
#       General_Merchandise       0.41      0.10      0.16       353
#                     Gifts       0.59      0.48      0.53       331
#                    Health       0.00      0.00      0.00         4
#     Health_and_Healthcare       0.60      0.42      0.49       380
#                  Holidays       0.00      0.00      0.00         2
# Holidays_and_Celebrations       0.62      0.41      0.49       115
#           Home_and_Garden       0.36      0.72      0.48      1568
#
#               avg / total       0.52      0.55      0.51      8362
#                            Antiques_and_Collectibles  Auctions  \
# Antiques_and_Collectibles                        251         0
# Auctions                                          16         7
# Beauty_Products                                    1         1
# Books                                             21         0
# Children                                           4         0
# Classifieds                                        6         0
# Clothing                                          16         2
# Computers                                          4         0
# Consumer_Electronics                              14         0
# Consumer_Information                               2         0
# Crafts                                             0         0
# Death_Care                                         0         0
# Entertainment                                      8         0
# Ethnic_and_Regional                                0         0
# Flowers                                            1         0
# Food                                               4         1
# General_Merchandise                               15         1
# Gifts                                              2         0
# Health                                             0         0
# Health_and_Healthcare                              4         1
# Holidays                                           0         0
# Holidays_and_Celebrations                          1         0
# Home_and_Garden                                   37         1
# Jewelry                                           16         1
# Music                                             12         1
# Niche                                              0         0
# Office_Products                                    4         0
# Other                                              8         1
# Pets                                               9         0
# Photography                                        7         0
# Publications                                       2         0
# Recreation                                        28         0
# Sporting_Goods                                    19         0
# Sports                                             0         0
# Tobacco                                            7         0
# Tools                                              0         0
# Toys_and_Games                                    10         0
# Travel_Items                                       0         0
# Weddings                                           0         0
#
#                            Beauty_Products  Books  Children  Classifieds  \
# Antiques_and_Collectibles                1     13         1            9
# Auctions                                 2      2         0            7
# Beauty_Products                        117      0         1            0
# Books                                    2    151         5            4
# Children                                 1      4       150            1
# Classifieds                              0      2         0          116
# Clothing                                 6      6        21            2
# Computers                                3      2         0            2
# Consumer_Electronics                     1      9         0            2
# Consumer_Information                     0      4         3            3
# Crafts                                   0      0         0            0
# Death_Care                               0      0         0            0
# Entertainment                            1     12         2            3
# Ethnic_and_Regional                      0      1         0            0
# Flowers                                  1      2         0            1
# Food                                     2      2         3            2
# General_Merchandise                      3      5         7            3
# Gifts                                    2      5         4            0
# Health                                   0      1         0            0
# Health_and_Healthcare                   14      9         7            3
# Holidays                                 0      0         0            0
# Holidays_and_Celebrations                0      1         1            0
# Home_and_Garden                          2      7         9            4
# Jewelry                                  2      5         1            0
# Music                                    1      4         3            5
# Niche                                    0      0         0            0
# Office_Products                          1      1         0            2
# Other                                   10      0         3            1
# Pets                                     0      9         2            1
# Photography                              0      1         0            0
# Publications                             0     20         0            0
# Recreation                               1      9         2            2
# Sporting_Goods                           2      4         2            6
# Sports                                   0      0         0            0
# Tobacco                                  0      0         1            0
# Tools                                    0      0         0            0
# Toys_and_Games                           1      1         4            1
# Travel_Items                             0      0         0            0
# Weddings                                 0      0         0            0
#
#                            Clothing  Computers  Consumer_Electronics  \
# Antiques_and_Collectibles        48          4                     8
# Auctions                          2          4                     2
# Beauty_Products                  17          2                     0
# Books                            28          3                     6
# Children                         41          3                     1
# Classifieds                       7          4                     1
# Clothing                        718         26                     8
# Computers                        35        282                    34
# Consumer_Electronics             54         28                   352
# Consumer_Information             19          1                    15
# Crafts                            3          0                     0
# Death_Care                        0          0                     1
# Entertainment                    37         11                     8
# Ethnic_and_Regional               2          0                     0
# Flowers                           5          0                     1
# Food                             30          6                     3
# General_Merchandise              48         23                    10
# Gifts                            20          1                     2
# Health                            0          0                     0
# Health_and_Healthcare            27         13                     7
# Holidays                          0          0                     0
# Holidays_and_Celebrations         9          1                     1
# Home_and_Garden                 108         15                    26
# Jewelry                          31          2                     1
# Music                            20          6                    12
# Niche                             2          0                     0
# Office_Products                  11         15                     1
# Other                            51          2                     7
# Pets                             33          7                     4
# Photography                      12          9                     7
# Publications                      9          4                     3
# Recreation                       60          9                    10
# Sporting_Goods                  127         15                    10
# Sports                            1          0                     0
# Tobacco                           6          0                     1
# Tools                             2          1                     1
# Toys_and_Games                    7          1                     2
# Travel_Items                      2          0                     1
# Weddings                          7          0                     0
#
#                            Consumer_Information    ...     Photography  \
# Antiques_and_Collectibles                     1    ...               5
# Auctions                                      0    ...               0
# Beauty_Products                               1    ...               0
# Books                                         2    ...               0
# Children                                      1    ...               3
# Classifieds                                   0    ...               0
# Clothing                                      1    ...               4
# Computers                                     0    ...               7
# Consumer_Electronics                          1    ...              13
# Consumer_Information                          6    ...               4
# Crafts                                        0    ...               0
# Death_Care                                    0    ...               0
# Entertainment                                 0    ...               4
# Ethnic_and_Regional                           0    ...               0
# Flowers                                       0    ...               0
# Food                                          0    ...               0
# General_Merchandise                           2    ...               2
# Gifts                                         0    ...               3
# Health                                        0    ...               0
# Health_and_Healthcare                         1    ...               0
# Holidays                                      0    ...               0
# Holidays_and_Celebrations                     0    ...               0
# Home_and_Garden                               1    ...               4
# Jewelry                                       0    ...               0
# Music                                         0    ...               4
# Niche                                         0    ...               0
# Office_Products                               0    ...               2
# Other                                         1    ...               0
# Pets                                          0    ...               2
# Photography                                   0    ...             107
# Publications                                  0    ...               0
# Recreation                                    0    ...               0
# Sporting_Goods                                1    ...               9
# Sports                                        0    ...               0
# Tobacco                                       0    ...               0
# Tools                                         1    ...               0
# Toys_and_Games                                1    ...               0
# Travel_Items                                  0    ...               1
# Weddings                                      1    ...               0
#
#                            Publications  Recreation  Sporting_Goods  Sports  \
# Antiques_and_Collectibles             6          27              17       0
# Auctions                              0           2               7       0
# Beauty_Products                       0           0               2       0
# Books                                 0          12              15       0
# Children                              0           2              10       0
# Classifieds                           0           3               2       0
# Clothing                              1          16              44       0
# Computers                             0           5              18       0
# Consumer_Electronics                  1           7              17       0
# Consumer_Information                  2           1               3       0
# Crafts                                0           1               1       0
# Death_Care                            0           0               0       0
# Entertainment                         0           9              12       0
# Ethnic_and_Regional                   0           0               0       0
# Flowers                               0           1               1       0
# Food                                  0           5              14       0
# General_Merchandise                   2          10              16       0
# Gifts                                 1           0              13       0
# Health                                0           0               0       0
# Health_and_Healthcare                 1           3              17       0
# Holidays                              0           0               0       0
# Holidays_and_Celebrations             0           2               4       0
# Home_and_Garden                       0          21              40       0
# Jewelry                               0           3               5       0
# Music                                 0           4               9       0
# Niche                                 0           0               0       0
# Office_Products                       0           5               9       0
# Other                                 0          15              13       0
# Pets                                  0          10              25       0
# Photography                           0           3              10       0
# Publications                         23           3               7       0
# Recreation                            0         282              63       0
# Sporting_Goods                        0          50             544       0
# Sports                                0           0               0       0
# Tobacco                               0           6               3       0
# Tools                                 0           3               8       0
# Toys_and_Games                        0          10               3       0
# Travel_Items                          0           2               2       0
# Weddings                              0           1               0       0
#
#                            Tobacco  Tools  Toys_and_Games  Travel_Items  \
# Antiques_and_Collectibles        0      0               1             0
# Auctions                         0      0               0             0
# Beauty_Products                  0      0               1             0
# Books                            0      0               0             0
# Children                         0      0               0             0
# Classifieds                      0      0               0             0
# Clothing                         0      0               0             0
# Computers                        0      1               0             0
# Consumer_Electronics             0      0               1             0
# Consumer_Information             0      0               0             0
# Crafts                           0      0               0             0
# Death_Care                       0      0               0             0
# Entertainment                    0      0               0             0
# Ethnic_and_Regional              0      0               0             0
# Flowers                          0      0               0             0
# Food                             0      0               0             0
# General_Merchandise              0      1               2             0
# Gifts                            0      0               1             0
# Health                           0      0               0             0
# Health_and_Healthcare            0      0               0             1
# Holidays                         0      0               0             0
# Holidays_and_Celebrations        0      0               0             0
# Home_and_Garden                  0      2               1             0
# Jewelry                          0      1               0             0
# Music                            0      0               0             0
# Niche                            0      0               0             0
# Office_Products                  0      0               0             0
# Other                            0      0               0             0
# Pets                             0      0               0             0
# Photography                      0      0               0             0
# Publications                     0      0               1             0
# Recreation                       0      2               1             0
# Sporting_Goods                   0      2               0             0
# Sports                           0      0               0             0
# Tobacco                          9      0               1             0
# Tools                            0      7               0             0
# Toys_and_Games                   1      0              15             0
# Travel_Items                     0      0               0             4
# Weddings                         0      0               0             0
#
#                            Weddings
# Antiques_and_Collectibles         0
# Auctions                          0
# Beauty_Products                   0
# Books                             0
# Children                          0
# Classifieds                       0
# Clothing                          0
# Computers                         0
# Consumer_Electronics              0
# Consumer_Information              0
# Crafts                            0
# Death_Care                        0
# Entertainment                     0
# Ethnic_and_Regional               0
# Flowers                           1
# Food                              0
# General_Merchandise               0
# Gifts                             0
# Health                            0
# Health_and_Healthcare             0
# Holidays                          0
# Holidays_and_Celebrations         0
# Home_and_Garden                   0
# Jewelry                           0
# Music                             0
# Niche                             0
# Office_Products                   0
# Other                             0
# Pets                              0
# Photography                       0
# Publications                      0
# Recreation                        1
# Sporting_Goods                    0
# Sports                            0
# Tobacco                           0
# Tools                             0
# Toys_and_Games                    0
# Travel_Items                      0
# Weddings                          1
#
# [39 rows x 39 columns]

# %%
predictions = np.zeros(categories_transformed.shape)

cv_f1_scores,cv_log_loss = [],[]
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
for dev_index, val_index in kf.split(range(tfidf.shape[0])):
        dev_X, val_X = tfidf[dev_index,:], tfidf[val_index,:]
        dev_y, val_y = categories_transformed[dev_index], categories_transformed[val_index]
        clf = MultinomialNB(fit_prior=False)
        clf.fit(dev_X,dev_y)
        preds_labels = clf.predict(val_X)
        predictions[val_index] = preds_labels
        cv_f1_scores.append(f1_score(val_y, preds_labels,average='weighted'))
        #cv_log_loss.append(log_loss(val_y,preds_labels))
        print(cv_f1_scores)
        #print(cv_log_loss)
# Out:
# [0.51398283339070661]
# [0.51398283339070661, 0.51441031798901704]
# [0.51398283339070661, 0.51441031798901704, 0.52891723328958573]
# [0.51398283339070661, 0.51441031798901704, 0.52891723328958573, 0.5156568326440889]
# [0.51398283339070661, 0.51441031798901704, 0.52891723328958573, 0.5156568326440889, 0.52130871052896199]

# %%
print metrics.classification_report(categories_transformed,predictions,labels=range(23),target_names=list(lbl.classes_))
pd.DataFrame(metrics.confusion_matrix(categories_transformed,predictions),columns=list(lbl.classes_),index=list(lbl.classes_))
# Out:
#                            precision    recall  f1-score   support
#
# Antiques_and_Collectibles       0.46      0.52      0.49       641
#                     Books       0.61      0.31      0.41       363
#                  Children       0.77      0.29      0.42       330
#               Classifieds       0.87      0.52      0.65       167
#                  Clothing       0.42      0.74      0.53      1136
#      Consumer_Electronics       0.66      0.56      0.61       640
#             Entertainment       0.68      0.37      0.48       405
#                   Flowers       0.89      0.72      0.80       258
#                      Food       0.60      0.79      0.69       773
#       General_Merchandise       0.35      0.03      0.05       353
#                     Gifts       0.56      0.46      0.50       331
#     Health_and_Healthcare       0.76      0.28      0.40       380
#           Home_and_Garden       0.47      0.72      0.56      1568
#                   Jewelry       0.78      0.72      0.75       492
#                     Music       0.84      0.58      0.69       433
#           Office_Products       0.68      0.29      0.41       252
#                     Other       0.69      0.07      0.13       258
#                      Pets       0.80      0.46      0.58       494
#               Photography       0.81      0.31      0.45       218
#                Recreation       0.63      0.41      0.50       684
#            Sporting_Goods       0.58      0.57      0.57      1040
#        other_categories_1       0.69      0.34      0.46       315
#        other_categories_2       0.31      0.51      0.38      1063
#
#               avg / total       0.58      0.53      0.52     12594
#                            Antiques_and_Collectibles  Books  Children  \
# Antiques_and_Collectibles                        336      2         0
# Books                                             29    114         1
# Children                                           4      3        96
# Classifieds                                        6      0         1
# Clothing                                          18      4         6
# Consumer_Electronics                              20      3         0
# Entertainment                                     12     11         1
# Flowers                                            3      1         0
# Food                                              11      1         0
# General_Merchandise                               21      1         3
# Gifts                                              5      1         1
# Health_and_Healthcare                              6      5         1
# Home_and_Garden                                   42      5         4
# Jewelry                                           18      2         0
# Music                                             13      4         0
# Office_Products                                    9      0         0
# Other                                             12      0         2
# Pets                                              14      4         0
# Photography                                        5      1         0
# Recreation                                        35      4         2
# Sporting_Goods                                    34      2         0
# other_categories_1                                 8      0         1
# other_categories_2                                68     20         6
#
#                            Classifieds  Clothing  Consumer_Electronics  \
# Antiques_and_Collectibles            3        70                     4
# Books                                2        28                     4
# Children                             0        67                     1
# Classifieds                         87         8                     0
# Clothing                             3       839                     2
# Consumer_Electronics                 0        67                   361
# Entertainment                        0        44                    12
# Flowers                              0         8                     1
# Food                                 0        41                     1
# General_Merchandise                  1        59                     6
# Gifts                                0        30                     2
# Health_and_Healthcare                0        50                     7
# Home_and_Garden                      0       112                    17
# Jewelry                              0        48                     3
# Music                                0        25                    16
# Office_Products                      0        18                     1
# Other                                0        72                     4
# Pets                                 0        43                     1
# Photography                          0        15                    25
# Recreation                           2        73                     8
# Sporting_Goods                       0       150                     9
# other_categories_1                   0        37                     2
# other_categories_2                   2       106                    56
#
#                            Entertainment  Flowers  Food  General_Merchandise  \
# Antiques_and_Collectibles              5        1    17                    0
# Books                                  8        0    14                    1
# Children                               2        0     9                    1
# Classifieds                            0        2     2                    0
# Clothing                               4        0    14                    0
# Consumer_Electronics                   3        0     1                    2
# Entertainment                        150        1    11                    0
# Flowers                                1      187    20                    0
# Food                                   3        4   613                    0
# General_Merchandise                    2        2    21                    9
# Gifts                                  0        3    42                    1
# Health_and_Healthcare                  0        0    29                    0
# Home_and_Garden                        3        5    59                    2
# Jewelry                                0        0     7                    0
# Music                                 16        0     6                    1
# Office_Products                        0        1     5                    0
# Other                                  4        0    20                    2
# Pets                                   0        1    38                    1
# Photography                            0        0     4                    0
# Recreation                             1        1    18                    3
# Sporting_Goods                         2        0     8                    0
# other_categories_1                     1        0    27                    1
# other_categories_2                    14        3    29                    2
#
#                                   ...          Jewelry  Music  \
# Antiques_and_Collectibles         ...               16      2
# Books                             ...                1      2
# Children                          ...                7      2
# Classifieds                       ...                0      0
# Clothing                          ...                7      1
# Consumer_Electronics              ...                1      4
# Entertainment                     ...                0     23
# Flowers                           ...                0      1
# Food                              ...                0      0
# General_Merchandise               ...               16      1
# Gifts                             ...                3      0
# Health_and_Healthcare             ...                0      0
# Home_and_Garden                   ...                9      1
# Jewelry                           ...              353      2
# Music                             ...                2    253
# Office_Products                   ...                0      0
# Other                             ...                8      1
# Pets                              ...                1      0
# Photography                       ...                1      1
# Recreation                        ...                5      3
# Sporting_Goods                    ...                3      2
# other_categories_1                ...                9      0
# other_categories_2                ...                8      3
#
#                            Office_Products  Other  Pets  Photography  \
# Antiques_and_Collectibles                6      3     0            2
# Books                                    0      0     5            0
# Children                                 1      0     1            0
# Classifieds                              0      0     1            0
# Clothing                                 4      0     1            0
# Consumer_Electronics                     0      0     2            5
# Entertainment                            3      0     2            0
# Flowers                                  0      0     0            0
# Food                                     0      0     1            0
# General_Merchandise                      0      1     5            0
# Gifts                                    4      0     2            1
# Health_and_Healthcare                    1      0     4            0
# Home_and_Garden                          6      0    16            2
# Jewelry                                  0      0     1            0
# Music                                    0      1     0            0
# Office_Products                         74      0     1            0
# Other                                    1     18     0            0
# Pets                                     0      1   225            0
# Photography                              0      0     0           67
# Recreation                               1      1     4            0
# Sporting_Goods                           1      1     7            4
# other_categories_1                       0      0     1            0
# other_categories_2                       7      0     1            2
#
#                            Recreation  Sporting_Goods  other_categories_1  \
# Antiques_and_Collectibles          23              17                   3
# Books                               5              10                   2
# Children                            1              12                   0
# Classifieds                         9               5                   0
# Clothing                            6              39                   2
# Consumer_Electronics                4              10                   3
# Entertainment                       4              18                   3
# Flowers                             0               1                   1
# Food                                2               6                   1
# General_Merchandise                 8              14                   7
# Gifts                               1               7                   1
# Health_and_Healthcare               2              34                   2
# Home_and_Garden                    13              30                  10
# Jewelry                             2              10                   1
# Music                               3              25                   0
# Office_Products                     1               2                   0
# Other                              16              19                   8
# Pets                                2              32                   1
# Photography                         1               8                   0
# Recreation                        279              79                   0
# Sporting_Goods                     38             590                   1
# other_categories_1                  0              13                 108
# other_categories_2                 20              35                   2
#
#                            other_categories_2
# Antiques_and_Collectibles                  50
# Books                                     102
# Children                                   34
# Classifieds                                38
# Clothing                                  120
# Consumer_Electronics                      101
# Entertainment                              66
# Flowers                                     7
# Food                                       28
# General_Merchandise                        89
# Gifts                                      32
# Health_and_Healthcare                      71
# Home_and_Garden                            97
# Jewelry                                    18
# Music                                      42
# Office_Products                            49
# Other                                      17
# Pets                                       34
# Photography                                60
# Recreation                                 52
# Sporting_Goods                             83
# other_categories_1                         24
# other_categories_2                        538
#
# [23 rows x 23 columns]

# %%
tfidf = url_text_dic['tfidf']
lbl = preprocessing.LabelEncoder()
categories_transformed = lbl.fit_transform(df['category'].values)
# analysing using only links
predictions = np.zeros(categories_transformed.shape)

cv_f1_scores,cv_log_loss = [],[]
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
for dev_index, val_index in kf.split(range(tfidf.shape[0])):
    dev_X, val_X = tfidf[dev_index,:], tfidf[val_index,:]
    dev_y, val_y = categories_transformed[dev_index], categories_transformed[val_index]
    clf = MultinomialNB(fit_prior=False)
    clf.fit(dev_X,dev_y)
    preds_labels = clf.predict(val_X)
    predictions[val_index] = preds_labels
    cv_f1_scores.append(f1_score(val_y, preds_labels,average='weighted'))
    #cv_log_loss.append(log_loss(val_y,preds_labels))
    print(cv_f1_scores)
    #print(cv_log_loss)
print metrics.classification_report(categories_transformed,predictions,labels=range(23),target_names=list(lbl.classes_))
pd.DataFrame(metrics.confusion_matrix(categories_transformed,predictions),columns=list(lbl.classes_),index=list(lbl.classes_))
# Out:
# [0.4998051078801925]
# [0.4998051078801925, 0.50785739976946398]
# [0.4998051078801925, 0.50785739976946398, 0.517651441632208]
# [0.4998051078801925, 0.50785739976946398, 0.517651441632208, 0.49937255194789115]
# [0.4998051078801925, 0.50785739976946398, 0.517651441632208, 0.49937255194789115, 0.50873131807956207]
#                            precision    recall  f1-score   support
#
# Antiques_and_Collectibles       0.20      0.55      0.29       641
#                     Books       0.42      0.46      0.44       363
#                  Children       0.57      0.47      0.51       330
#               Classifieds       0.50      0.74      0.59       167
#                  Clothing       0.50      0.57      0.54      1136
#      Consumer_Electronics       0.58      0.56      0.57       640
#             Entertainment       0.54      0.43      0.48       405
#                   Flowers       0.69      0.81      0.75       258
#                      Food       0.53      0.73      0.61       773
#       General_Merchandise       0.34      0.10      0.15       353
#                     Gifts       0.47      0.53      0.50       331
#     Health_and_Healthcare       0.54      0.39      0.45       380
#           Home_and_Garden       0.63      0.48      0.54      1568
#                   Jewelry       0.71      0.71      0.71       492
#                     Music       0.71      0.59      0.64       433
#           Office_Products       0.64      0.56      0.60       252
#                     Other       0.52      0.21      0.29       258
#                      Pets       0.65      0.52      0.58       494
#               Photography       0.58      0.45      0.51       218
#                Recreation       0.57      0.39      0.46       684
#            Sporting_Goods       0.70      0.45      0.55      1040
#        other_categories_1       0.61      0.53      0.56       315
#        other_categories_2       0.32      0.37      0.34      1063
#
#               avg / total       0.54      0.50      0.51     12594
#                            Antiques_and_Collectibles  Books  Children  \
# Antiques_and_Collectibles                        353     21         1
# Books                                             50    168         6
# Children                                          28      6       154
# Classifieds                                       15      3         0
# Clothing                                         128     17        23
# Consumer_Electronics                              80      8         2
# Entertainment                                     51     17         1
# Flowers                                           17      2         1
# Food                                              75      8         0
# General_Merchandise                               52      7         9
# Gifts                                             32      3         7
# Health_and_Healthcare                             40     13         5
# Home_and_Garden                                  206     14        20
# Jewelry                                           57      9         1
# Music                                             48      6         2
# Office_Products                                   16      3         1
# Other                                             27      2         3
# Pets                                              47     11         0
# Photography                                       32      2         1
# Recreation                                       106     16         3
# Sporting_Goods                                   122     16         4
# other_categories_1                                29      1         5
# other_categories_2                               163     47        22
#
#                            Classifieds  Clothing  Consumer_Electronics  \
# Antiques_and_Collectibles           16        33                     5
# Books                                7        10                     6
# Children                             1        25                     1
# Classifieds                        123         3                     0
# Clothing                            15       651                     9
# Consumer_Electronics                 3        37                   357
# Entertainment                        6        17                    16
# Flowers                              3         2                     0
# Food                                 3        23                     3
# General_Merchandise                  5        37                    13
# Gifts                                2        17                     4
# Health_and_Healthcare                2        18                    11
# Home_and_Garden                     10        61                    36
# Jewelry                              0        21                     4
# Music                                5        12                    14
# Office_Products                      0         9                     1
# Other                                0        38                     7
# Pets                                 1        23                     5
# Photography                          0         7                    15
# Recreation                           7        53                    13
# Sporting_Goods                      20       117                    18
# other_categories_1                   0        11                     1
# other_categories_2                  18        65                    81
#
#                            Entertainment  Flowers  Food  General_Merchandise  \
# Antiques_and_Collectibles             13        2    29                    2
# Books                                 11        0    19                    2
# Children                               6        2    16                    3
# Classifieds                            0        2     4                    0
# Clothing                              13        5    37                    8
# Consumer_Electronics                   5        1     9                    1
# Entertainment                        174        2    15                    0
# Flowers                                0      209     8                    0
# Food                                   3       10   566                    3
# General_Merchandise                    3        3    27                   35
# Gifts                                  0       18    23                    2
# Health_and_Healthcare                  5        0    22                    2
# Home_and_Garden                        8       31   109                    7
# Jewelry                                0        2     8                    1
# Music                                 24        3     5                    1
# Office_Products                        0        2     4                    2
# Other                                  6        0    18                    3
# Pets                                   4        3    33                    2
# Photography                            0        0     4                    0
# Recreation                             7        3    22                   10
# Sporting_Goods                         6        0    27                    4
# other_categories_1                     3        1    24                    5
# other_categories_2                    33        4    39                    9
#
#                                   ...          Jewelry  Music  \
# Antiques_and_Collectibles         ...               25      5
# Books                             ...                1      9
# Children                          ...                8      5
# Classifieds                       ...                0      0
# Clothing                          ...               13      4
# Consumer_Electronics              ...                2      6
# Entertainment                     ...                1     22
# Flowers                           ...                0      0
# Food                              ...                1      3
# General_Merchandise               ...               20      3
# Gifts                             ...                3      0
# Health_and_Healthcare             ...                1      0
# Home_and_Garden                   ...               20      9
# Jewelry                           ...              351      2
# Music                             ...                5    254
# Office_Products                   ...                0      1
# Other                             ...               10      4
# Pets                              ...                2      0
# Photography                       ...                2      2
# Recreation                        ...                6      4
# Sporting_Goods                    ...                5     12
# other_categories_1                ...                8      1
# other_categories_2                ...                7     11
#
#                            Office_Products  Other  Pets  Photography  \
# Antiques_and_Collectibles               12      8     6            5
# Books                                    3      1     7            0
# Children                                 2      0     5            2
# Classifieds                              1      0     1            0
# Clothing                                 9      9     7            5
# Consumer_Electronics                     1      0     1            8
# Entertainment                            1      2     3            3
# Flowers                                  0      0     1            1
# Food                                     1      2     7            0
# General_Merchandise                      1      4     8            1
# Gifts                                    7      1     0            2
# Health_and_Healthcare                    4      0    12            1
# Home_and_Garden                         19      7    33           12
# Jewelry                                  0      1     1            1
# Music                                    0      2     1            2
# Office_Products                        141      1     2            3
# Other                                    0     53     6            1
# Pets                                     2      1   259            3
# Photography                              1      0     0           99
# Recreation                               0      2    11            1
# Sporting_Goods                           3      3    12           13
# other_categories_1                       1      0     4            0
# other_categories_2                      12      5     9            8
#
#                            Recreation  Sporting_Goods  other_categories_1  \
# Antiques_and_Collectibles          21               8                   2
# Books                               3               3                   2
# Children                            1               6                   2
# Classifieds                         2               0                   0
# Clothing                            7              27                   9
# Consumer_Electronics                5               9                   2
# Entertainment                       6               5                   8
# Flowers                             0               0                   0
# Food                                2               5                   2
# General_Merchandise                 6               6                  11
# Gifts                               0               2                   5
# Health_and_Healthcare               4              10                  13
# Home_and_Garden                    24              21                  14
# Jewelry                             2               4                   4
# Music                               4               4                   1
# Office_Products                     1               1                   1
# Other                              21               4                  16
# Pets                                5              15                   2
# Photography                         1               4                   2
# Recreation                        264              50                   3
# Sporting_Goods                     53             472                   1
# other_categories_1                  0               2                 166
# other_categories_2                 34              19                   8
#
#                            other_categories_2
# Antiques_and_Collectibles                  29
# Books                                      39
# Children                                   19
# Classifieds                                10
# Clothing                                  100
# Consumer_Electronics                       80
# Entertainment                              31
# Flowers                                     4
# Food                                       28
# General_Merchandise                        49
# Gifts                                      12
# Health_and_Healthcare                      45
# Home_and_Garden                           109
# Jewelry                                    10
# Music                                      26
# Office_Products                            23
# Other                                      12
# Pets                                       30
# Photography                                28
# Recreation                                 42
# Sporting_Goods                             71
# other_categories_1                         18
# other_categories_2                        390
#
# [23 rows x 23 columns]

# %%
tmp = pd.DataFrame(metrics.confusion_matrix(categories_transformed,predictions),columns=list(lbl.classes_),index=list(lbl.classes_))

# %%
tmp.ix['Home_and_Garden',:]
# Out:
# Antiques_and_Collectibles    206
# Books                         14
# Children                      20
# Classifieds                   10
# Clothing                      61
# Consumer_Electronics          36
# Entertainment                  8
# Flowers                       31
# Food                         109
# General_Merchandise            7
# Gifts                         33
# Health_and_Healthcare         15
# Home_and_Garden              750
# Jewelry                       20
# Music                          9
# Office_Products               19
# Other                          7
# Pets                          33
# Photography                   12
# Recreation                    24
# Sporting_Goods                21
# other_categories_1            14
# other_categories_2           109
# Name: Home_and_Garden, dtype: int64
